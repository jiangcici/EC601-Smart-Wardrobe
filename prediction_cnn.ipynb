# %%
from keras.models import load_model
from keras.preprocessing.image import img_to_array
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

model=load_model('./keras_cnn_model_our_dataset.h5')

img = cv2.imread('IMG_0538.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = cv2.resize(gray,(200,200),interpolation=cv2.INTER_NEAREST)
#gray = (255-gray)
plt.imshow(gray)
x = img_to_array(gray)
inputarray = x[np.newaxis,...]

classes = model.predict_classes(inputarray)

print(classes)
# Out:
# 1/1 [==============================] - 0s
# [3]
